# %%
import pandas as pd
import spacy
import en_core_web_sm # Language model to be used for nlp()
nlp = en_core_web_sm.load()

# %%
fox = pd.read_csv("fox_followers.csv", encoding = "unicode_escape")
cnn = pd.read_csv("cnn_followers.csv", encoding = "unicode_escape")

# %%
fox.head()
# Out:
#    Unnamed: 0              user_id  \
# 0           1            948997266
# 1           2           2762605662
# 2           3  1074363473080000512
# 3           4            560692070
# 4           5  1088956155500490753
#
#                                          description place_full_name country  \
# 0                              Iowa State University             NaN     NaN
# 1  Long live Britain and America and all the true...             NaN     NaN
# 2  Intelligent, patients,loyal ,kind ,love ,compa...             NaN     NaN
# 3           #LongLiveBigBen <U+0001F64F><U+0001F3FF>             NaN     NaN
# 4  IM A SURVIVOR AKA A WALKING MIRACLE AKA A PHEN...             NaN     NaN
#
#    friends_count account_lang lang           created_at
# 0            500           en   en  2019-02-01 10:58:26
# 1            795           en   en  2019-01-31 21:29:32
# 2            380           en   en  2019-02-01 09:49:38
# 3            842           en   en  2019-01-23 04:23:34
# 4            974           en   en  2019-02-01 09:57:34

# %%
cnn.head()
# Out:
#    Unnamed: 0              user_id  \
# 0           1  1089863600246849536
# 1           2   791969492427341824
# 2           3   957862952261926913
# 3           4   816924548796792833
# 4           5  1052194171795243008
#
#                                          description place_full_name country  \
# 0                                         optimistic             NaN     NaN
# 1  fav YouTuber: @moesargi\r\nfav music artist: @...             NaN     NaN
# 2  Follower of Living god @donnypangilinan and th...             NaN     NaN
# 3  I love to help anyone that's Serious about Mak...             NaN     NaN
# 4      praising and worshiping my God makes me happy             NaN     NaN
#
#    friends_count account_lang lang           created_at
# 0            341           en   en  2019-01-31 10:34:58
# 1            730           en   en  2019-01-31 10:39:38
# 2            634           en   en  2019-01-31 10:24:58
# 3           4790           en   en  2019-01-27 18:54:23
# 4            258           en   en  2019-01-22 10:17:57

# %%
def return_NER(df):
    
    """Takes in a pandas dataframe formatted as expected: 
    
       ['Unnamed: 0', 'user_id', 'description', 'place_full_name', 'country',
           'friends_count', 'account_lang', 'lang', 'created_at']
        
        Uses the spacy library to perform Named Entity Recognition (amongst other text analysis).
        
        Stores and outputs the results for each user in a new dataframe, which contains either a single value 
        or a set of values for each Named Entity.
       """
    
    
    df_result = pd.DataFrame(columns=["user_id", "Description", "NER", 
                                        "GPE", "LOC", "ORG", "NORP", "WORK_OF_ART", "Other"],
                              index = range(len(df)))

    for i in range(len(df)):
        df_result.iloc[i, 0] = df.iloc[i, 1] # Transfering user_id to the result df
        df_result.iloc[i, 1] = df.iloc[i, 2] # Transfer the description

        NER = []
        GPE = set() # set () avoids duplicates
        LOC = set()
        ORG = set()
        NORP = set()
        WORK_OF_ART = set()
        other = set()

        text = str(df.iloc[i, 2]) # Description
        
        doc = nlp(text) # One single call to spacy, returns the whole text analysis

        for ent in doc.ents: # doc.ents stores everything related to NER
            
            NER.append((ent.text, ent.label_)) # Raw NER
            
            # Filters the entities based on type
            if ent.label_ == "GPE": # Country, cities, states
                GPE.add(ent.text)
            elif ent.label_ == "LOC": # Locations others than GPEs 
                LOC.add(ent.text)
            elif ent.label_ == "ORG": # Organizations
                ORG.add(ent.text)
            elif ent.label_ == "NORP": # Nationalities, religious or political groups
                NORP.add(ent.text)
            elif ent.label_ == "WORK_OF_ART": # Titles of books, songs, etc. (can help determining hobbies)
                WORK_OF_ART.add(ent.text)            
            else:
                other.add((ent.text, ent.label_))
        
        
        results = [NER, GPE, LOC, ORG, NORP, WORK_OF_ART, other]
        
        # Loops over the sets to incorporate them into the final dataframe
        for j in range(len(results)):
            if len(results[j]) == 0:
                pass
            elif len(results[j]) == 1:
                # .pop method works both on lists & sets
                df_result.iloc[i, j+2] = results[j].pop() #j+2 = column index (2 first columns are id & raw text)
            else:
                df_result.iloc[i, j+2] = results[j] # If several results for one tag, stores them as a set in the df
    return df_result

# %%
NER_fox = return_NER(fox)
NER_fox.to_csv("NER_fox.csv")

# %%
NER_cnn = return_NER(cnn)
NER_cnn.to_csv("NER_cnn.csv")

# %%
NER_cnn
# Out:
#                   user_id                                        Description  \
# 0     1089863600246849536                                         optimistic
# 1      791969492427341824  fav YouTuber: @moesargi\r\nfav music artist: @...
# 2      957862952261926913  Follower of Living god @donnypangilinan and th...
# 3      816924548796792833  I love to help anyone that's Serious about Mak...
# 4     1052194171795243008      praising and worshiping my God makes me happy
# 5     1054963261098078209  Dnnmndnjnj<U+0923><U+0927><U+0927><U+0927><U+0...
# 6               420585058  Everton following, movie watching, book loving...
# 7              3133777988                         utes 22 <U+0392>T<U+03A0>
# 8     1046770645823033344  A new and permanent fixture on the professiona...
# 9     1085016029560897537  BORN IN 01.09.2000\r\nLIVES IN UDUVIL :JAFFNA:...
# 10              302140545    Road trips, rock music <U+0001F3B6><U+0001F3B6>
# 11    1032178726556114945               Junior SEO Specialist @SpotcapGlobal
# 12             4264403054  NIPPON DATA SYSTEMS LIMITED  is a provider of ...
# 13              160145616  Entrepreneur*Actress*Model*Face of Preety Woma...
# 14    1073475974069551104                                       Entrepreneur
# 15    1072897701375729664  A curious soul, would be #author interested in...
# 16    1069485759898550273                              politically conscious
# 17    1065069836097617925  Store: https://t.co/9FQm4TRN1q\r\nIf you like ...
# 18     851486080738131970           I plan to live for ever. so far, so good
# 19              153708617                         Australian ARMY - 95 liner
# 20             2437367476             Everybody L<U+262F><U+FE0F>ves chrisay
# 21              602989684                                  Sofware Developer
# 22              306765931  Cr7<U+0001F4A5>Vijay<U+2665><U+FE0F>ARR<U+0001...
# 23    1084142979433017346                          Main interest in politics
# 24             2347367479                                  live and let live
# 25    1089755779643699200                                 MiLL. <U+0001F3E1>
# 26    1065471147368562688  Hi we're Victoria and Stephan! We are cousins ...
# 27     987373268947689472  cool calm collective person\r\nkeep it real #PSO#
# 28     909681155422674944        Global Entertainment, Bighit Entertainment.
# 29     991011055475265537                      LAWYER IN A PRIVATE PRACTICE.
# ...                   ...                                                ...
# 3921           1122869946  I am a simple,cool-headed and reserved dude wh...
# 3922             33279769  Adviseur bij https://t.co/6xIqH7093e / entrepr...
# 3923             31279143                                        IG: maquels
# 3924            242289683  <U+064A><U+0627> <U+0628><U+0644><U+0627><U+06...
# 3925           2998222145  Nurse, wife, cat parent, ultimate housework da...
# 3926   919130561498767360                           LUCIA ZWANE <U+0001F5A4>
# 3927  1088498674408116224   Law of Attraction  Ask, Believe, Receive  ...
# 3928   872764930373668864  An online platform for citizens and candidate ...
# 3929            856394042                                   live learn teach
# 3930  1081041438060802048  Progressive Democrat. Vegan. Will follow back ...
# 3931   951449534504222720  <U+0001F3C4> Persistent overcome Resistance <U...
# 3932   952584282551103489  || Biggest Fan of @emraanhashmi || Class 12th ...
# 3933   766234045764296708  <U+0001F3A7> R&B/Soul, Jazz <U+2764><U+FE0F>Ar...
# 3934  1089055121366048768                                       bogara karak
# 3935   903338343672545280  #resist Just an old retired man still interest...
# 3936            324547615  Nurse, Blackhawks, Cubs, Bears, Music is life,...
# 3937   901386377681448960                     Ms Dhoni big fan\r\n7300135096
# 3938             41873019                     Life is full of many surprises
# 3939  1025642576265859073                         BEING HUMAN@@MANOJ POKHREL
# 3940            474188531  #Pinstripepride<U+26BE><U+FE0F> #BeTheFight <U...
# 3941            880474069                  On the pursuit of peace and lagom
# 3942   873193502238162946  #ELECTRICAL  #INDIAN ...working on better tomo...
# 3943  1077402638994550784                                       I am reading
# 3944           1394195198  Piscean<U+0001F433>  whatever you put out int...
# 3945  1078376321502400514                                     Im that bitch
# 3946           2497322112  I am a momma of three wonderful children and a...
# 3947  1089077381942398976                             am proud of my culture
# 3948  1089071797461504000                                  New Zim who this?
# 3949  1057201186456117248  kind<U+0001F60A>\r\nnetworker<U+0001F917>\r\no...
# 3950           3324611183                                             #Grace
#
#                                                     NER  \
# 0                                                   NaN
# 1     [(YouTuber, PERSON), (@5sos, ORG), (@sarah J.,...
# 2     [(@donnypangilinan, GPE), (@KissesDelavin, PER...
# 3             [(Serious, GPE), (#socialmedia #, MONEY)]
# 4                                                   NaN
# 5                                     (Dnnmndnjnj, ORG)
# 6                                        (Everton, ORG)
# 7                                                   NaN
# 8     [(the 9th - 11th August 2019, DATE), (dc@zeuse...
# 9     [(01.09.2000, CARDINAL), (UDUVIL, GPE), (JAFFN...
# 10                                                  NaN
# 11                                                  NaN
# 12    [(NIPPON DATA SYSTEMS LIMITED  , ORG), (Indust...
# 13                                       (Child, MONEY)
# 14                                                  NaN
# 15    [(Israel, GPE), (Poetry, MONEY), (Psychiatry, ...
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                    [(Australian, NORP), (ARMY, ORG)]
# 20                                                  NaN
# 21                                                  NaN
# 22    [(Cr7<U+0001F4A5>Vijay, ORG), (ARR<U+0001F4AB,...
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                 [(Victoria, PERSON), (Stephan, GPE)]
# 27                                       (#PSO#, MONEY)
# 28    [(Global Entertainment, ORG), (Bighit Entertai...
# 29                                        (LAWYER, GPE)
# ...                                                 ...
# 3921                                                NaN
# 3922  [(Adviseur, PERSON), (https://t.co/6xIqH7093e,...
# 3923                                          (IG, ORG)
# 3924  [(U+0648><U+0645><U+064E><U+0644><U+0626><U+06...
# 3925                                                NaN
# 3926                                 (LUCIA ZWANE, ORG)
# 3927                                                NaN
# 3928                                                NaN
# 3929                                                NaN
# 3930  [(Democrat, NORP), (Vegan, PERSON), (Democrats...
# 3931   [(Persistent, ORG), (CA, ORG), (Finance &, ORG)]
# 3932  [(@emraanhashmi, PERSON), (12th, ORDINAL), (Bi...
# 3933  [(R&B/Soul, ORG), (Jazz, ORG), (Art Design & A...
# 3934                                                NaN
# 3935                                   (#resist, MONEY)
# 3936  [(Cubs, ORG), (Music, ORG), (Animal Lover, PER...
# 3937                [(Dhoni, NORP), (7300135096, DATE)]
# 3938                                                NaN
# 3939                                                NaN
# 3940                                (BeTheFight, MONEY)
# 3941                                                NaN
# 3942  [(ELECTRICAL  , ORG), (INDIAN, NORP), (tomorro...
# 3943                                                NaN
# 3944                                     (Piscean, GPE)
# 3945                                                NaN
# 3946                                  (three, CARDINAL)
# 3947                                                NaN
# 3948                                                NaN
# 3949                                       (NX, PERSON)
# 3950                                     (Grace, MONEY)
#
#                                                     GPE  LOC  \
# 0                                                   NaN  NaN
# 1                                                   NaN  NaN
# 2                                      @donnypangilinan  NaN
# 3                                               Serious  NaN
# 4                                                   NaN  NaN
# 5                                                   NaN  NaN
# 6                                                   NaN  NaN
# 7                                                   NaN  NaN
# 8                                                   NaN  NaN
# 9                           {SRI LANKA, JAFFNA, UDUVIL}  NaN
# 10                                                  NaN  NaN
# 11                                                  NaN  NaN
# 12                                                  NaN  NaN
# 13                                                  NaN  NaN
# 14                                                  NaN  NaN
# 15                                               Israel  NaN
# 16                                                  NaN  NaN
# 17                                                  NaN  NaN
# 18                                                  NaN  NaN
# 19                                                  NaN  NaN
# 20                                                  NaN  NaN
# 21                                                  NaN  NaN
# 22                                                  NaN  NaN
# 23                                                  NaN  NaN
# 24                                                  NaN  NaN
# 25                                                  NaN  NaN
# 26                                              Stephan  NaN
# 27                                                  NaN  NaN
# 28                                                  NaN  NaN
# 29                                               LAWYER  NaN
# ...                                                 ...  ...
# 3921                                                NaN  NaN
# 3922                                                NaN  NaN
# 3923                                                NaN  NaN
# 3924             U+0627><U+0644><U+0623><U+0631><U+0636  NaN
# 3925                                                NaN  NaN
# 3926                                                NaN  NaN
# 3927                                                NaN  NaN
# 3928                                                NaN  NaN
# 3929                                                NaN  NaN
# 3930  {U+0001F499><U+0001F30A><U+0001F308><U+0001F9E...  NaN
# 3931                                                NaN  NaN
# 3932                                                NaN  NaN
# 3933                                                NaN  NaN
# 3934                                                NaN  NaN
# 3935                                                NaN  NaN
# 3936                                                NaN  NaN
# 3937                                                NaN  NaN
# 3938                                                NaN  NaN
# 3939                                                NaN  NaN
# 3940                                                NaN  NaN
# 3941                                                NaN  NaN
# 3942                                                NaN  NaN
# 3943                                                NaN  NaN
# 3944                                            Piscean  NaN
# 3945                                                NaN  NaN
# 3946                                                NaN  NaN
# 3947                                                NaN  NaN
# 3948                                                NaN  NaN
# 3949                                                NaN  NaN
# 3950                                                NaN  NaN
#
#                                                     ORG  \
# 0                                                   NaN
# 1                                                 @5sos
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                            Dnnmndnjnj
# 6                                               Everton
# 7                                                   NaN
# 8                                   dc@zeusevents.co.uk
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12    {Cloud Solutions, Industry Specific Software A...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                 ARMY
# 20                                                  NaN
# 21                                                  NaN
# 22          {MSD, Cr7<U+0001F4A5>Vijay, ARR<U+0001F4AB}
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28         {Bighit Entertainment, Global Entertainment}
# 29                                                  NaN
# ...                                                 ...
# 3921                                                NaN
# 3922                            https://t.co/6xIqH7093e
# 3923                                                 IG
# 3924                   U+0648><U+0623><U+062F><U+0628>.
# 3925                                                NaN
# 3926                                        LUCIA ZWANE
# 3927                                                NaN
# 3928                                                NaN
# 3929                                                NaN
# 3930                                   EqualPay #Resist
# 3931                        {Finance &, Persistent, CA}
# 3932                                             Bihari
# 3933        {Jazz, R&B/Soul, Art Design & Architecture}
# 3934                                                NaN
# 3935                                                NaN
# 3936                             {Music, Pitbull, Cubs}
# 3937                                                NaN
# 3938                                                NaN
# 3939                                                NaN
# 3940                                                NaN
# 3941                                                NaN
# 3942                                       ELECTRICAL
# 3943                                                NaN
# 3944                                                NaN
# 3945                                                NaN
# 3946                                                NaN
# 3947                                                NaN
# 3948                                                NaN
# 3949                                                NaN
# 3950                                                NaN
#
#                        NORP WORK_OF_ART  \
# 0                       NaN         NaN
# 1                       NaN         NaN
# 2                       NaN         NaN
# 3                       NaN         NaN
# 4                       NaN         NaN
# 5                       NaN         NaN
# 6                       NaN         NaN
# 7                       NaN         NaN
# 8                       NaN         NaN
# 9                       NaN         NaN
# 10                      NaN         NaN
# 11                      NaN         NaN
# 12                      NaN         NaN
# 13                      NaN         NaN
# 14                      NaN         NaN
# 15                      NaN         NaN
# 16                      NaN         NaN
# 17                      NaN         NaN
# 18                      NaN         NaN
# 19               Australian         NaN
# 20                      NaN         NaN
# 21                      NaN         NaN
# 22                      NaN         NaN
# 23                      NaN         NaN
# 24                      NaN         NaN
# 25                      NaN         NaN
# 26                      NaN         NaN
# 27                      NaN         NaN
# 28                      NaN         NaN
# 29                      NaN         NaN
# ...                     ...         ...
# 3921                    NaN         NaN
# 3922                    NaN         NaN
# 3923                    NaN         NaN
# 3924                    NaN         NaN
# 3925                    NaN         NaN
# 3926                    NaN         NaN
# 3927                    NaN         NaN
# 3928                    NaN         NaN
# 3929                    NaN         NaN
# 3930  {Democrat, Democrats}         NaN
# 3931                    NaN         NaN
# 3932                 Indian         NaN
# 3933                    NaN         NaN
# 3934                    NaN         NaN
# 3935                    NaN         NaN
# 3936                    NaN         NaN
# 3937                  Dhoni         NaN
# 3938                    NaN         NaN
# 3939                    NaN         NaN
# 3940                    NaN         NaN
# 3941                    NaN         NaN
# 3942                 INDIAN         NaN
# 3943                    NaN         NaN
# 3944                    NaN         NaN
# 3945                    NaN         NaN
# 3946                    NaN         NaN
# 3947                    NaN         NaN
# 3948                    NaN         NaN
# 3949                    NaN         NaN
# 3950                    NaN         NaN
#
#                                                   Other
# 0                                                   NaN
# 1             {(@sarah J., PERSON), (YouTuber, PERSON)}
# 2          {(DonKiss, MONEY), (@KissesDelavin, PERSON)}
# 3                               (#socialmedia #, MONEY)
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                    (the 9th - 11th August 2019, DATE)
# 9     {(01.09.2000, CARDINAL), (J/KOKUVIL HINDU COLL...
# 10                                                  NaN
# 11                                                  NaN
# 12                        {(#ERP, MONEY), (SCM, MONEY)}
# 13                                       (Child, MONEY)
# 14                                                  NaN
# 15               {(Poetry, MONEY), (Psychiatry, MONEY)}
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                   (Victoria, PERSON)
# 27                                       (#PSO#, MONEY)
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3921                                                NaN
# 3922              {(Adviseur, PERSON), (Grunn, PERSON)}
# 3923                                                NaN
# 3924  (U+0648><U+0645><U+064E><U+0644><U+0626><U+062...
# 3925                                                NaN
# 3926                                                NaN
# 3927                                                NaN
# 3928                                                NaN
# 3929                                                NaN
# 3930      {(#BillionaireTax #, MONEY), (Vegan, PERSON)}
# 3931                                                NaN
# 3932         {(@emraanhashmi, PERSON), (12th, ORDINAL)}
# 3933                                                NaN
# 3934                                                NaN
# 3935                                   (#resist, MONEY)
# 3936        {(Snapchat, MONEY), (Animal Lover, PERSON)}
# 3937                                 (7300135096, DATE)
# 3938                                                NaN
# 3939                                                NaN
# 3940                                (BeTheFight, MONEY)
# 3941                                                NaN
# 3942                                   (tomorrow, DATE)
# 3943                                                NaN
# 3944                                                NaN
# 3945                                                NaN
# 3946                                  (three, CARDINAL)
# 3947                                                NaN
# 3948                                                NaN
# 3949                                       (NX, PERSON)
# 3950                                     (Grace, MONEY)
#
# [3951 rows x 9 columns]
